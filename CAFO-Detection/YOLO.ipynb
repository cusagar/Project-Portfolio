# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Access Google Drive Folder
import os
os.chdir("drive/MyDrive")

# %%
# Create YOLOv8 root folder
# !mkdir yolov8-obb

# %%
# Go to YOLOv8 root folder
# %cd yolov8-obb
# Out:
# /content/drive/MyDrive/yolov8-obb

# %%
# Install YOLOv8
# %pip install ultralytics

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.101 🚀 Python-3.11.11 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.2/107.7 GB disk)

# %%
# Download YOLOv8 model
# !wget https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8x.pt

# %%
# !mkdir data

# %%
# Go to data folder
# %cd data
# Out:
# /content/drive/MyDrive/yolov8-obb/data

# %%
/content/drive/MyDrive/yolov8-obb/data/pp.v1i.yolov8-obb.zip

# %%
# Unzip Dataset
# !unzip pp.v1i.yolov8-obb.zip
# Out:
# Archive:  pp.v1i.yolov8-obb.zip
#   inflating: README.dataset.txt
#   inflating: README.roboflow.txt
#   inflating: data.yaml
#    creating: test/
#    creating: test/images/
#  extracting: test/images/poultry_cafo_f__north-carolina_burke_4911_287_6_1_0_17_-253_13761_jpeg.rf.50852841cc97e2184012e059abb32e19.jpg
#  extracting: test/images/poultry_cafo_f__north-carolina_caldwell_13097_287_6_1_0_17_-126_13795_jpeg.rf.3fbe127a09715a46109fcf3f3f9043ac.jpg
#  extracting: test/images/poultry_cafo_f__north-carolina_caldwell_5609_287_6_1_0_17_-187_13864_jpeg.rf.9bf682b91cd23892aa8957c83e23b774.jpg
#  extracting: test/images/poultry_cafo_f__north-carolina_caswell_3771_287_6_1_0_17_494_13993_jpeg.rf.4b91cafff40b56cc309a3198c4b9c484.jpg
#  extracting: test/images/poultry_cafo_f__north-carolina_caswell_8394_287_6_1_0_17_534_14006_jpeg.rf.07c14511b888441f089184bb8ab6f869.jpg
# ...

# %%
# Get Absolute Path
import os

print(os.getcwd())
# Out:
# /content/drive/MyDrive/yolov8-obb/data

# %%
# Back to the root folder
# %cd ../
# Out:
# /content/drive/MyDrive/yolov8-obb

# %%
# Training
# !yolo obb train model=yolov8l-obb.pt data=data/data.yaml workers=2 batch=2 imgsz=640 device=cpu epochs=100 patience=50 name=yolov8_obb
# Out:
# Ultralytics 8.3.101 🚀 Python-3.11.11 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('/content/drive/MyDrive/yolov8-obb')

# %%
# Install YOLOv8
# %pip install ultralytics

# %%
# !yolo obb val model=runs/obb/yolov8_obb5/weights/best.pt data=data/data.yaml name=yolov8_obb_car_val split=val
# Out:
# Ultralytics 8.3.101 🚀 Python-3.11.11 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# YOLOv8l-obb summary (fused): 121 layers, 44,457,372 parameters, 0 gradients, 168.5 GFLOPs
# val: Scanning /content/drive/MyDrive/yolov8-obb/data/valid/labels.cache... 28 images, 0 backgrounds, 0 corrupt: 100% 28/28 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0% 0/2 [00:00<?, ?it/s]WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  50% 1/2 [01:27<01:27, 87.08s/it]WARNING ⚠️ NMS time limit 2.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [02:22<00:00, 71.02s/it]
#                    all         28         29      0.284      0.478      0.311      0.125
#         poultry_cafo_f         10         10      0.297        0.7      0.551      0.196
# ...

# %%
# !yolo obb val model=runs/obb/yolov8_obb5/weights/best.pt data=data/data.yaml name=yolov8_obb_car_test split=test
# Out:
# Ultralytics 8.3.101 🚀 Python-3.11.11 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# YOLOv8l-obb summary (fused): 121 layers, 44,457,372 parameters, 0 gradients, 168.5 GFLOPs
# val: Scanning /content/drive/MyDrive/yolov8-obb/data/test/labels... 31 images, 0 backgrounds, 0 corrupt: 100% 31/31 [00:00<00:00, 79.36it/s]
# val: New cache created: /content/drive/MyDrive/yolov8-obb/data/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0% 0/2 [00:00<?, ?it/s]WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  50% 1/2 [01:15<01:15, 75.96s/it]WARNING ⚠️ NMS time limit 2.750s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [02:21<00:00, 70.82s/it]
#                    all         31         31      0.799      0.297      0.373      0.178
# ...
